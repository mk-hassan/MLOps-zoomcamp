# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %% [markdown]
# ## what is this ?
# 1. xgboost module is imported to use the XGBoost model. see "XGBoost.ipynb" where i tried to make a simple regression model
# 2. hyperopt:It's a library that used some **bayesian methods** to try to find the best set of hyperparameters
#    In terms of hyperopt your model will be just a function that takes some input(combination of hyper parameters) and outputs some values. that function called ***objective function***
#    1. fmin: Runs the optmization loop to find the best hyperparameter set. (the hp combination that produces the lowest RMSE)
#       Used to minimize the objective function(outputs of the model), it depends on the evaluation metric you may need the maximum output.
#    2. tpe: The algorithm used to pick the next best parameters to try (TPE = Tree-structured Parzen Estimator)
#    3. hp: library that contains a bunch of different methods to define the search space (the ranges of each hyperparameter that we will use).
#    4. STATUS_OK: signal that we will send at the end of each run to tell hyperopt that the objective function has run successfully.
#    5. Trials: will keep track of the information of each run
# 3. scope: used to cast values inside the **search space** to integer, float, etc.
#
# summery:
# trying different hyper-parameter set generated by the **hp** module, each new set is selected using **tpe** algorithm. the **fmin** is used to run the objective function with different parameter set and selects the parameter set that produces the minimum RMSE. So from its name it tries to minimize the RMSE by running the model again and again with different hyper-parameter set.

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('../data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID'
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/MLOps-zoomcamp/02. Experiment Tracking/mlruns/1', creation_time=1749581082720, experiment_id='1', last_update_time=1749581082720, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# DMatrix is an optimized data structure used by XGBoost to:
# Store your features (X_train, X_val) and labels (y_train, y_val)
# Speed up training (it’s faster than using raw NumPy arrays or Pandas)
# Handle things like missing values, sparse data, and caching internally

train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
from sklearn.metrics import root_mean_squared_error
"""
the training works as follows: 
    Start training (up to 1000 rounds)
    After each round:
        Train a new tree
        Evaluate on the validation set
        Check if performance improved
    If it stops improving for 50 rounds in a row → training stops early
    The model automatically keeps the best version it saw during training
"""
def objective(params: dict) -> dict:
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100, # Try training up to 1000 trees (boosting rounds)
            evals=[(valid, 'validation')], # While training, also evaluate the model on this validation set
            early_stopping_rounds=20 # If the validation score doesn't improve for 50 rounds, stop training early
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
"""
hp.quniform => 
"""
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    # this tells the xgboost training algorithm to use RMSE metric in validation after each round
    # this indicates when to do early stopping to avoid overfitting and wasting time
    'objective': 'reg:squarederror',
    # For predictability
    'seed': 42
}

"""
the fn parameter is the objective function that is responsible for running the model
it's expected to take the params as input
and return a dictionary contains two keys "loss" and  "status"
"""
best_result = fmin(
    fn=objective,
    space=search_space,
    # This tells Hyperopt how to choose the next set of parameters. tpe (Tree-structured Parzen Estimator) is a smart algorithm that learns from past trials to pick better values next time.
    algo=tpe.suggest,
    # number of runs, each run with different Hypter-parameter set
    max_evals=10,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:11.07441
# [1]	validation-rmse:10.14551
# [2]	validation-rmse:9.39334
# [3]	validation-rmse:8.78916
# [4]	validation-rmse:8.30966
# [5]	validation-rmse:7.92920
# [6]	validation-rmse:7.62874
# [7]	validation-rmse:7.39467
# [8]	validation-rmse:7.21007
# [9]	validation-rmse:7.06695
# [10]	validation-rmse:6.95387
# [11]	validation-rmse:6.86513
# [12]	validation-rmse:6.79510
# [13]	validation-rmse:6.73945
# [14]	validation-rmse:6.69434
# [15]	validation-rmse:6.65814
# [16]	validation-rmse:6.62886
# [17]	validation-rmse:6.60488
# [18]	validation-rmse:6.58593
# [19]	validation-rmse:6.57032
# [20]	validation-rmse:6.55687
# [21]	validation-rmse:6.54489
# [22]	validation-rmse:6.53462
# [23]	validation-rmse:6.52629
# [24]	validation-rmse:6.51947
# [25]	validation-rmse:6.51296
# [26]	validation-rmse:6.50672
# [27]	validation-rmse:6.50193
# [28]	validation-rmse:6.49715
# [29]	validation-rmse:6.49380
# [30]	validation-rmse:6.49061
# [31]	validation-rmse:6.48674
# [32]	validation-rmse:6.48271
# [33]	validation-rmse:6.47976
# [34]	validation-rmse:6.47712
# [35]	validation-rmse:6.47525
# [36]	validation-rmse:6.47388
# [37]	validation-rmse:6.47199
# [38]	validation-rmse:6.46988
# [39]	validation-rmse:6.46869
# [40]	validation-rmse:6.46752
# [41]	validation-rmse:6.46615
# [42]	validation-rmse:6.46500
# [43]	validation-rmse:6.46339
# [44]	validation-rmse:6.46244
# [45]	validation-rmse:6.46136
# [46]	validation-rmse:6.46021
# [47]	validation-rmse:6.45908
# [48]	validation-rmse:6.45833
# [49]	validation-rmse:6.45694
# [50]	validation-rmse:6.45561
# [51]	validation-rmse:6.45468
# [52]	validation-rmse:6.45371
# [53]	validation-rmse:6.45279
# [54]	validation-rmse:6.45131
# [55]	validation-rmse:6.45062
# [56]	validation-rmse:6.44970
# [57]	validation-rmse:6.44894
# [58]	validation-rmse:6.44819
# [59]	validation-rmse:6.44737
# [60]	validation-rmse:6.44669
# [61]	validation-rmse:6.44590
# [62]	validation-rmse:6.44485
# [63]	validation-rmse:6.44376
# [64]	validation-rmse:6.44298
# [65]	validation-rmse:6.44241
# [66]	validation-rmse:6.44162
# [67]	validation-rmse:6.44035
# [68]	validation-rmse:6.43917
# [69]	validation-rmse:6.43837
# [70]	validation-rmse:6.43785
# [71]	validation-rmse:6.43738
# [72]	validation-rmse:6.43646
# [73]	validation-rmse:6.43579
# [74]	validation-rmse:6.43536
# [75]	validation-rmse:6.43428
# [76]	validation-rmse:6.43322
# [77]	validation-rmse:6.43268
# [78]	validation-rmse:6.43206
# [79]	validation-rmse:6.43145
# [80]	validation-rmse:6.43088
# [81]	validation-rmse:6.43042
# [82]	validation-rmse:6.42986
# [83]	validation-rmse:6.42905
# [84]	validation-rmse:6.42849
# [85]	validation-rmse:6.42797
# [86]	validation-rmse:6.42741
# [87]	validation-rmse:6.42690
# [88]	validation-rmse:6.42660
# [89]	validation-rmse:6.42601
# [90]	validation-rmse:6.42549
# [91]	validation-rmse:6.42463
# [92]	validation-rmse:6.42384
# [93]	validation-rmse:6.42345
# [94]	validation-rmse:6.42289
# [95]	validation-rmse:6.42221
# [96]	validation-rmse:6.42152
# [97]	validation-rmse:6.42132
# [98]	validation-rmse:6.42109
# [99]	validation-rmse:6.42072
# [0]	validation-rmse:11.41151
# [1]	validation-rmse:10.71598
# [2]	validation-rmse:10.11548
# [3]	validation-rmse:9.59858
# [4]	validation-rmse:9.15598
# [5]	validation-rmse:8.77806
# [6]	validation-rmse:8.45701
# [7]	validation-rmse:8.18495
# [8]	validation-rmse:7.95539
# [9]	validation-rmse:7.76172
# [10]	validation-rmse:7.59791
# [11]	validation-rmse:7.46015
# [12]	validation-rmse:7.34434
# [13]	validation-rmse:7.24707
# [14]	validation-rmse:7.16570
# [15]	validation-rmse:7.09728
# [16]	validation-rmse:7.03959
# [17]	validation-rmse:6.99108
# [18]	validation-rmse:6.94994
# [19]	validation-rmse:6.91364
# [20]	validation-rmse:6.88203
# [21]	validation-rmse:6.85536
# [22]	validation-rmse:6.83228
# [23]	validation-rmse:6.81253
# [24]	validation-rmse:6.79616
# [25]	validation-rmse:6.78120
# [26]	validation-rmse:6.76817
# [27]	validation-rmse:6.75698
# [28]	validation-rmse:6.74714
# [29]	validation-rmse:6.73924
# [30]	validation-rmse:6.73196
# [31]	validation-rmse:6.72568
# [32]	validation-rmse:6.72002
# [33]	validation-rmse:6.71455
# [34]	validation-rmse:6.71006
# [35]	validation-rmse:6.70579
# [36]	validation-rmse:6.70218
# [37]	validation-rmse:6.69872
# [38]	validation-rmse:6.69383
# [39]	validation-rmse:6.68963
# [40]	validation-rmse:6.68584
# [41]	validation-rmse:6.68376
# [42]	validation-rmse:6.68172
# [43]	validation-rmse:6.67885
# [44]	validation-rmse:6.67743
# [45]	validation-rmse:6.67536
# [46]	validation-rmse:6.67337
# [47]	validation-rmse:6.67164
# [48]	validation-rmse:6.67001
# [49]	validation-rmse:6.66858
# [50]	validation-rmse:6.66722
# [51]	validation-rmse:6.66631
# [52]	validation-rmse:6.66469
# [53]	validation-rmse:6.66385
# [54]	validation-rmse:6.66293
# [55]	validation-rmse:6.66164
# [56]	validation-rmse:6.66098
# [57]	validation-rmse:6.66010
# [58]	validation-rmse:6.65963
# [59]	validation-rmse:6.65862
# [60]	validation-rmse:6.65809
# [61]	validation-rmse:6.65734
# [62]	validation-rmse:6.65694
# [63]	validation-rmse:6.65609
# [64]	validation-rmse:6.65562
# [65]	validation-rmse:6.65511
# [66]	validation-rmse:6.65485
# [67]	validation-rmse:6.65418
# [68]	validation-rmse:6.65376
# [69]	validation-rmse:6.65312
# [70]	validation-rmse:6.65271
# [71]	validation-rmse:6.65232
# [72]	validation-rmse:6.65204
# [73]	validation-rmse:6.65184
# [74]	validation-rmse:6.65161
# [75]	validation-rmse:6.65103
# [76]	validation-rmse:6.65079
# [77]	validation-rmse:6.65046
# [78]	validation-rmse:6.65026
# [79]	validation-rmse:6.64990
# [80]	validation-rmse:6.64963
# [81]	validation-rmse:6.64948
# [82]	validation-rmse:6.64927
# [83]	validation-rmse:6.64910
# [84]	validation-rmse:6.64850
# [85]	validation-rmse:6.64838
# [86]	validation-rmse:6.64820
# [87]	validation-rmse:6.64804
# [88]	validation-rmse:6.64783
# [89]	validation-rmse:6.64768
# [90]	validation-rmse:6.64739
# [91]	validation-rmse:6.64726
# [92]	validation-rmse:6.64694
# [93]	validation-rmse:6.64677
# [94]	validation-rmse:6.64656
# [95]	validation-rmse:6.64646
# [96]	validation-rmse:6.64607
# [97]	validation-rmse:6.64595
# [98]	validation-rmse:6.64550
# [99]	validation-rmse:6.64541
# [0]	validation-rmse:11.69417
# [1]	validation-rmse:11.21747
# [2]	validation-rmse:10.78115
# [3]	validation-rmse:10.38139
# [4]	validation-rmse:10.01622
# [5]	validation-rmse:9.68344
# [6]	validation-rmse:9.37968
# [7]	validation-rmse:9.10264
# [8]	validation-rmse:8.85163
# [9]	validation-rmse:8.62318
# [10]	validation-rmse:8.41735
# [11]	validation-rmse:8.23114
# [12]	validation-rmse:8.06277
# [13]	validation-rmse:7.91100
# [14]	validation-rmse:7.77357
# [15]	validation-rmse:7.65059
# [16]	validation-rmse:7.54020
# [17]	validation-rmse:7.44049
# [18]	validation-rmse:7.34986
# [19]	validation-rmse:7.26901
# [20]	validation-rmse:7.19605
# [21]	validation-rmse:7.13040
# [22]	validation-rmse:7.07082
# [23]	validation-rmse:7.01783
# [24]	validation-rmse:6.96870
# [25]	validation-rmse:6.92503
# [26]	validation-rmse:6.88626
# [27]	validation-rmse:6.85084
# [28]	validation-rmse:6.81856
# [29]	validation-rmse:6.78964
# [30]	validation-rmse:6.76316
# [31]	validation-rmse:6.73947
# [32]	validation-rmse:6.71767
# [33]	validation-rmse:6.69845
# [34]	validation-rmse:6.68052
# [35]	validation-rmse:6.66397
# [36]	validation-rmse:6.64904
# [37]	validation-rmse:6.63565
# [38]	validation-rmse:6.62259
# [39]	validation-rmse:6.61131
# [40]	validation-rmse:6.60063
# [41]	validation-rmse:6.59073
# [42]	validation-rmse:6.58161
# [43]	validation-rmse:6.57396
# [44]	validation-rmse:6.56648
# [45]	validation-rmse:6.55920
# [46]	validation-rmse:6.55296
# [47]	validation-rmse:6.54672
# [48]	validation-rmse:6.54112
# [49]	validation-rmse:6.53626
# [50]	validation-rmse:6.53119
# [51]	validation-rmse:6.52649
# [52]	validation-rmse:6.52231
# [53]	validation-rmse:6.51833
# [54]	validation-rmse:6.51455
# [55]	validation-rmse:6.51137
# [56]	validation-rmse:6.50806
# [57]	validation-rmse:6.50499
# [58]	validation-rmse:6.50164
# [59]	validation-rmse:6.49918
# [60]	validation-rmse:6.49652
# [61]	validation-rmse:6.49396
# [62]	validation-rmse:6.49126
# [63]	validation-rmse:6.48886
# [64]	validation-rmse:6.48633
# [65]	validation-rmse:6.48446
# [66]	validation-rmse:6.48280
# [67]	validation-rmse:6.48096
# [68]	validation-rmse:6.47910
# [69]	validation-rmse:6.47765
# [70]	validation-rmse:6.47614
# [71]	validation-rmse:6.47442
# [72]	validation-rmse:6.47296
# [73]	validation-rmse:6.47157
# [74]	validation-rmse:6.47025
# [75]	validation-rmse:6.46878
# [76]	validation-rmse:6.46790
# [77]	validation-rmse:6.46664
# [78]	validation-rmse:6.46554
# [79]	validation-rmse:6.46457
# [80]	validation-rmse:6.46369
# [81]	validation-rmse:6.46280
# [82]	validation-rmse:6.46209
# [83]	validation-rmse:6.46157
# [84]	validation-rmse:6.46084
# [85]	validation-rmse:6.46035
# [86]	validation-rmse:6.45932
# [87]	validation-rmse:6.45878
# [88]	validation-rmse:6.45841
# [89]	validation-rmse:6.45725
# [90]	validation-rmse:6.45652
# [91]	validation-rmse:6.45586
# [92]	validation-rmse:6.45533
# [93]	validation-rmse:6.45477
# [94]	validation-rmse:6.45402
# [95]	validation-rmse:6.45333
# [96]	validation-rmse:6.45266
# [97]	validation-rmse:6.45214
# [98]	validation-rmse:6.45133
# [99]	validation-rmse:6.45065
# [0]	validation-rmse:9.75672
# [1]	validation-rmse:8.34270
# [2]	validation-rmse:7.56529
# [3]	validation-rmse:7.15051
# [4]	validation-rmse:6.92763
# [5]	validation-rmse:6.80132
# [6]	validation-rmse:6.72952
# [7]	validation-rmse:6.68636
# [8]	validation-rmse:6.66133
# [9]	validation-rmse:6.64372
# [10]	validation-rmse:6.63341
# [11]	validation-rmse:6.62452
# [12]	validation-rmse:6.62038
# [13]	validation-rmse:6.61788
# [14]	validation-rmse:6.61548
# [15]	validation-rmse:6.61340
# [16]	validation-rmse:6.61152
# [17]	validation-rmse:6.60822
# [18]	validation-rmse:6.60485
# [19]	validation-rmse:6.60315
# [20]	validation-rmse:6.59885
# [21]	validation-rmse:6.59529
# [22]	validation-rmse:6.59328
# [23]	validation-rmse:6.59084
# [24]	validation-rmse:6.58953
# [25]	validation-rmse:6.58732
# [26]	validation-rmse:6.58487
# [27]	validation-rmse:6.58168
# [28]	validation-rmse:6.57961
# [29]	validation-rmse:6.57717
# [30]	validation-rmse:6.57262
# [31]	validation-rmse:6.57009
# [32]	validation-rmse:6.56828
# [33]	validation-rmse:6.56692
# [34]	validation-rmse:6.56355
# [35]	validation-rmse:6.56150
# [36]	validation-rmse:6.55904
# [37]	validation-rmse:6.55793
# [38]	validation-rmse:6.55489
# [39]	validation-rmse:6.55334
# [40]	validation-rmse:6.55026
# [41]	validation-rmse:6.54857
# [42]	validation-rmse:6.54626
# [43]	validation-rmse:6.54451
# [44]	validation-rmse:6.54254
# [45]	validation-rmse:6.54061
# [46]	validation-rmse:6.53981
# [47]	validation-rmse:6.53858
# [48]	validation-rmse:6.53716
# [49]	validation-rmse:6.53643
# [50]	validation-rmse:6.53491
# [51]	validation-rmse:6.53298
# [52]	validation-rmse:6.53200
# [53]	validation-rmse:6.53006
# [54]	validation-rmse:6.52874
# [55]	validation-rmse:6.52742
# [56]	validation-rmse:6.52648
# [57]	validation-rmse:6.52520
# [58]	validation-rmse:6.52465
# [59]	validation-rmse:6.52393
# [60]	validation-rmse:6.52246
# [61]	validation-rmse:6.52074
# [62]	validation-rmse:6.51893
# [63]	validation-rmse:6.51828
# [64]	validation-rmse:6.51790
# [65]	validation-rmse:6.51702
# [66]	validation-rmse:6.51524
# [67]	validation-rmse:6.51417
# [68]	validation-rmse:6.51288
# [69]	validation-rmse:6.51100
# [70]	validation-rmse:6.51046
# [71]	validation-rmse:6.50975
# [72]	validation-rmse:6.50843
# [73]	validation-rmse:6.50732
# [74]	validation-rmse:6.50631
# [75]	validation-rmse:6.50481
# [76]	validation-rmse:6.50512
# [77]	validation-rmse:6.50387
# [78]	validation-rmse:6.50098
# [79]	validation-rmse:6.49980
# [80]	validation-rmse:6.49970
# [81]	validation-rmse:6.49809
# [82]	validation-rmse:6.49745
# [83]	validation-rmse:6.49654
# [84]	validation-rmse:6.49507
# [85]	validation-rmse:6.49284
# [86]	validation-rmse:6.49160
# [87]	validation-rmse:6.49091
# [88]	validation-rmse:6.49066
# [89]	validation-rmse:6.48958
# [90]	validation-rmse:6.48915
# [91]	validation-rmse:6.48890
# [92]	validation-rmse:6.48777
# [93]	validation-rmse:6.48690
# [94]	validation-rmse:6.48598
# [95]	validation-rmse:6.48495
# [96]	validation-rmse:6.48440
# [97]	validation-rmse:6.48336
# [98]	validation-rmse:6.48184
# [99]	validation-rmse:6.48102
# [0]	validation-rmse:11.76455
# [1]	validation-rmse:11.34950
# [2]	validation-rmse:10.96656
# [3]	validation-rmse:10.61239
# [4]	validation-rmse:10.28695
# [5]	validation-rmse:9.98639
# [6]	validation-rmse:9.71069
# [7]	validation-rmse:9.45813
# [8]	validation-rmse:9.22708
# [9]	validation-rmse:9.01404
# [10]	validation-rmse:8.81986
# [11]	validation-rmse:8.64233
# [12]	validation-rmse:8.48076
# [13]	validation-rmse:8.33341
# [14]	validation-rmse:8.19945
# [15]	validation-rmse:8.07636
# [16]	validation-rmse:7.96426
# [17]	validation-rmse:7.86311
# [18]	validation-rmse:7.77060
# [19]	validation-rmse:7.68621
# [20]	validation-rmse:7.60901
# [21]	validation-rmse:7.54003
# [22]	validation-rmse:7.47713
# [23]	validation-rmse:7.41932
# [24]	validation-rmse:7.36739
# [25]	validation-rmse:7.32041
# [26]	validation-rmse:7.27672
# [27]	validation-rmse:7.23740
# [28]	validation-rmse:7.20180
# [29]	validation-rmse:7.16888
# [30]	validation-rmse:7.13941
# [31]	validation-rmse:7.11254
# [32]	validation-rmse:7.08770
# [33]	validation-rmse:7.06498
# [34]	validation-rmse:7.04462
# [35]	validation-rmse:7.02649
# [36]	validation-rmse:7.00980
# [37]	validation-rmse:6.99409
# [38]	validation-rmse:6.98000
# [39]	validation-rmse:6.96714
# [40]	validation-rmse:6.95552
# [41]	validation-rmse:6.94441
# [42]	validation-rmse:6.93503
# [43]	validation-rmse:6.92578
# [44]	validation-rmse:6.91717
# [45]	validation-rmse:6.90961
# [46]	validation-rmse:6.90214
# [47]	validation-rmse:6.89520
# [48]	validation-rmse:6.88894
# [49]	validation-rmse:6.88310
# [50]	validation-rmse:6.87725
# [51]	validation-rmse:6.87205
# [52]	validation-rmse:6.86752
# [53]	validation-rmse:6.86328
# [54]	validation-rmse:6.85855
# [55]	validation-rmse:6.85437
# [56]	validation-rmse:6.85088
# [57]	validation-rmse:6.84863
# [58]	validation-rmse:6.84570
# [59]	validation-rmse:6.84270
# [60]	validation-rmse:6.84059
# [61]	validation-rmse:6.83789
# [62]	validation-rmse:6.83619
# [63]	validation-rmse:6.83385
# [64]	validation-rmse:6.83225
# [65]	validation-rmse:6.82951
# [66]	validation-rmse:6.82698
# [67]	validation-rmse:6.82551
# [68]	validation-rmse:6.82370
# [69]	validation-rmse:6.82209
# [70]	validation-rmse:6.82087
# [71]	validation-rmse:6.81902
# [72]	validation-rmse:6.81799
# [73]	validation-rmse:6.81641
# [74]	validation-rmse:6.81554
# [75]	validation-rmse:6.81376
# [76]	validation-rmse:6.81263
# [77]	validation-rmse:6.81224
# [78]	validation-rmse:6.81182
# [79]	validation-rmse:6.81100
# [80]	validation-rmse:6.81047
# [81]	validation-rmse:6.80986
# [82]	validation-rmse:6.80863
# [83]	validation-rmse:6.80803
# [84]	validation-rmse:6.80737
# [85]	validation-rmse:6.80692
# [86]	validation-rmse:6.80655
# [87]	validation-rmse:6.80538
# [88]	validation-rmse:6.80472
# [89]	validation-rmse:6.80427
# [90]	validation-rmse:6.80347
# [91]	validation-rmse:6.80239
# [92]	validation-rmse:6.80180
# [93]	validation-rmse:6.80112
# [94]	validation-rmse:6.80055
# [95]	validation-rmse:6.79946
# [96]	validation-rmse:6.79896
# [97]	validation-rmse:6.79854
# [98]	validation-rmse:6.79817
# [99]	validation-rmse:6.79778
# [0]	validation-rmse:8.19275
# [1]	validation-rmse:7.07209
# [2]	validation-rmse:6.77788
# [3]	validation-rmse:6.67196
# [4]	validation-rmse:6.63044
# [5]	validation-rmse:6.60842
# [6]	validation-rmse:6.58798
# [7]	validation-rmse:6.58278
# [8]	validation-rmse:6.57478
# [9]	validation-rmse:6.57188
# [10]	validation-rmse:6.56901
# [11]	validation-rmse:6.56346
# [12]	validation-rmse:6.56097
# [13]	validation-rmse:6.55640
# [14]	validation-rmse:6.55521
# [15]	validation-rmse:6.55388
# [16]	validation-rmse:6.55270
# [17]	validation-rmse:6.55214
# [18]	validation-rmse:6.55010
# [19]	validation-rmse:6.54858
# [20]	validation-rmse:6.54787
# [21]	validation-rmse:6.54751
# [22]	validation-rmse:6.54712
# [23]	validation-rmse:6.54492
# [24]	validation-rmse:6.54366
# [25]	validation-rmse:6.54283
# [26]	validation-rmse:6.54226
# [27]	validation-rmse:6.54106
# [28]	validation-rmse:6.54036
# [29]	validation-rmse:6.54051
# [30]	validation-rmse:6.53920
# [31]	validation-rmse:6.53907
# [32]	validation-rmse:6.53863
# [33]	validation-rmse:6.53893
# [34]	validation-rmse:6.53788
# [35]	validation-rmse:6.53799
# [36]	validation-rmse:6.53752
# [37]	validation-rmse:6.53668
# [38]	validation-rmse:6.53685
# [39]	validation-rmse:6.53723
# [40]	validation-rmse:6.53671
# [41]	validation-rmse:6.53614
# [42]	validation-rmse:6.53643
# [43]	validation-rmse:6.53530
# [44]	validation-rmse:6.53530
# [45]	validation-rmse:6.53466
# [46]	validation-rmse:6.53453
# [47]	validation-rmse:6.53465
# [48]	validation-rmse:6.53419
# [49]	validation-rmse:6.53414
# [50]	validation-rmse:6.53410
# [51]	validation-rmse:6.53338
# [52]	validation-rmse:6.53387
# [53]	validation-rmse:6.53421
# [54]	validation-rmse:6.53338
# [55]	validation-rmse:6.53377
# [56]	validation-rmse:6.53287
# [57]	validation-rmse:6.53262
# [58]	validation-rmse:6.53199
# [59]	validation-rmse:6.53207
# [60]	validation-rmse:6.53212
# [61]	validation-rmse:6.53199
# [62]	validation-rmse:6.53184
# [63]	validation-rmse:6.53124
# [64]	validation-rmse:6.53121
# [65]	validation-rmse:6.53090
# [66]	validation-rmse:6.53077
# [67]	validation-rmse:6.53080
# [68]	validation-rmse:6.53040
# [69]	validation-rmse:6.53042
# [70]	validation-rmse:6.53011
# [71]	validation-rmse:6.52949
# [72]	validation-rmse:6.52971
# [73]	validation-rmse:6.52930
# [74]	validation-rmse:6.52935
# [75]	validation-rmse:6.52932
# [76]	validation-rmse:6.52939
# [77]	validation-rmse:6.52903
# [78]	validation-rmse:6.52818
# [79]	validation-rmse:6.52903
# [80]	validation-rmse:6.52890
# [81]	validation-rmse:6.52847
# [82]	validation-rmse:6.52816
# [83]	validation-rmse:6.52828
# [84]	validation-rmse:6.52858
# [85]	validation-rmse:6.52935
# [86]	validation-rmse:6.52936
# [87]	validation-rmse:6.52864
# [88]	validation-rmse:6.52831
# [89]	validation-rmse:6.52833
# [90]	validation-rmse:6.52763
# [91]	validation-rmse:6.52727
# [92]	validation-rmse:6.52673
# [93]	validation-rmse:6.52671
# [94]	validation-rmse:6.52787
# [95]	validation-rmse:6.52732
# [96]	validation-rmse:6.52751
# [97]	validation-rmse:6.52738
# [98]	validation-rmse:6.52724
# [99]	validation-rmse:6.52711
# [0]	validation-rmse:11.70823
# [1]	validation-rmse:11.24429
# [2]	validation-rmse:10.81892
# [3]	validation-rmse:10.42961
# [4]	validation-rmse:10.07338
# [5]	validation-rmse:9.74801
# [6]	validation-rmse:9.45122
# [7]	validation-rmse:9.18111
# [8]	validation-rmse:8.93623
# [9]	validation-rmse:8.71402
# [10]	validation-rmse:8.51238
# [11]	validation-rmse:8.32999
# [12]	validation-rmse:8.16489
# [13]	validation-rmse:8.01587
# [14]	validation-rmse:7.88084
# [15]	validation-rmse:7.75997
# [16]	validation-rmse:7.65074
# [17]	validation-rmse:7.55249
# [18]	validation-rmse:7.46419
# [19]	validation-rmse:7.38398
# [20]	validation-rmse:7.31236
# [21]	validation-rmse:7.24755
# [22]	validation-rmse:7.18936
# [23]	validation-rmse:7.13690
# [24]	validation-rmse:7.08969
# [25]	validation-rmse:7.04650
# [26]	validation-rmse:7.00620
# [27]	validation-rmse:6.97006
# [28]	validation-rmse:6.93686
# [29]	validation-rmse:6.90706
# [30]	validation-rmse:6.88044
# ...
# [99]	validation-rmse:6.55598
# [0]	validation-rmse:11.65641
# [1]	validation-rmse:11.14813
# [2]	validation-rmse:10.68574
# [3]	validation-rmse:10.26421
# [4]	validation-rmse:9.88213
# [5]	validation-rmse:9.53492
# [6]	validation-rmse:9.22268
# [7]	validation-rmse:8.93914
# [8]	validation-rmse:8.68309
# [9]	validation-rmse:8.45363
# [10]	validation-rmse:8.24733
# [11]	validation-rmse:8.06091
# [12]	validation-rmse:7.89570
# [13]	validation-rmse:7.74545
# [14]	validation-rmse:7.61146
# [15]	validation-rmse:7.49190
# [16]	validation-rmse:7.38524
# [17]	validation-rmse:7.29063
# [18]	validation-rmse:7.20510
# [19]	validation-rmse:7.12936
# [20]	validation-rmse:7.06096
# [21]	validation-rmse:7.00094
# [22]	validation-rmse:6.94597
# [23]	validation-rmse:6.89824
# [24]	validation-rmse:6.85446
# [25]	validation-rmse:6.81548
# [26]	validation-rmse:6.78070
# [27]	validation-rmse:6.74898
# [28]	validation-rmse:6.71989
# [29]	validation-rmse:6.69555
# [30]	validation-rmse:6.67299
# [31]	validation-rmse:6.65151
# [32]	validation-rmse:6.63385
# [33]	validation-rmse:6.61697
# [34]	validation-rmse:6.60104
# [35]	validation-rmse:6.58731
# [36]	validation-rmse:6.57431
# [37]	validation-rmse:6.56257
# [38]	validation-rmse:6.55203
# [39]	validation-rmse:6.54221
# [40]	validation-rmse:6.53382
# [41]	validation-rmse:6.52492
# [42]	validation-rmse:6.51718
# [43]	validation-rmse:6.50959
# [44]	validation-rmse:6.50342
# [45]	validation-rmse:6.49788
# [46]	validation-rmse:6.49229
# [47]	validation-rmse:6.48734
# [48]	validation-rmse:6.48255
# [49]	validation-rmse:6.47794
# [50]	validation-rmse:6.47413
# [51]	validation-rmse:6.47001
# [52]	validation-rmse:6.46638
# [53]	validation-rmse:6.46311
# [54]	validation-rmse:6.46006
# [55]	validation-rmse:6.45658
# [56]	validation-rmse:6.45352
# [57]	validation-rmse:6.45104
# [58]	validation-rmse:6.44864
# [59]	validation-rmse:6.44606
# [60]	validation-rmse:6.44329
# [61]	validation-rmse:6.44103
# [62]	validation-rmse:6.43934
# [63]	validation-rmse:6.43769
# [64]	validation-rmse:6.43633
# [65]	validation-rmse:6.43474
# [66]	validation-rmse:6.43345
# [67]	validation-rmse:6.43211
# [68]	validation-rmse:6.43123
# [69]	validation-rmse:6.43029
# [70]	validation-rmse:6.42924
# [71]	validation-rmse:6.42831
# [72]	validation-rmse:6.42751
# [73]	validation-rmse:6.42666
# [74]	validation-rmse:6.42568
# [75]	validation-rmse:6.42468
# [76]	validation-rmse:6.42365
# [77]	validation-rmse:6.42254
# [78]	validation-rmse:6.42177
# [79]	validation-rmse:6.42133
# [80]	validation-rmse:6.42093
# [81]	validation-rmse:6.42024
# [82]	validation-rmse:6.41962
# [83]	validation-rmse:6.41913
# [84]	validation-rmse:6.41853
# [85]	validation-rmse:6.41788
# [86]	validation-rmse:6.41730
# [87]	validation-rmse:6.41646
# [88]	validation-rmse:6.41593
# [89]	validation-rmse:6.41518
# [90]	validation-rmse:6.41466
# [91]	validation-rmse:6.41394
# [92]	validation-rmse:6.41328
# [93]	validation-rmse:6.41248
# [94]	validation-rmse:6.41175
# [95]	validation-rmse:6.41126
# [96]	validation-rmse:6.41109
# [97]	validation-rmse:6.41050
# [98]	validation-rmse:6.40984
# [99]	validation-rmse:6.40933
# [0]	validation-rmse:11.30969
# [1]	validation-rmse:10.54117
# [2]	validation-rmse:9.89074
# [3]	validation-rmse:9.34322
# [4]	validation-rmse:8.88530
# [5]	validation-rmse:8.50395
# [6]	validation-rmse:8.18773
# [7]	validation-rmse:7.92668
# [8]	validation-rmse:7.71078
# [9]	validation-rmse:7.53294
# [10]	validation-rmse:7.38701
# [11]	validation-rmse:7.26758
# [12]	validation-rmse:7.16898
# [13]	validation-rmse:7.08841
# [14]	validation-rmse:7.02280
# [15]	validation-rmse:6.96840
# [16]	validation-rmse:6.92329
# [17]	validation-rmse:6.88411
# [18]	validation-rmse:6.85082
# [19]	validation-rmse:6.82450
# [20]	validation-rmse:6.80054
# [21]	validation-rmse:6.78069
# [22]	validation-rmse:6.76401
# [23]	validation-rmse:6.74948
# [24]	validation-rmse:6.73690
# [25]	validation-rmse:6.72633
# [26]	validation-rmse:6.71703
# [27]	validation-rmse:6.70923
# [28]	validation-rmse:6.70200
# [29]	validation-rmse:6.69432
# [30]	validation-rmse:6.68853
# [31]	validation-rmse:6.68335
# [32]	validation-rmse:6.67800
# [33]	validation-rmse:6.67374
# [34]	validation-rmse:6.66749
# [35]	validation-rmse:6.66205
# [36]	validation-rmse:6.65762
# [37]	validation-rmse:6.65399
# [38]	validation-rmse:6.65093
# [39]	validation-rmse:6.64806
# [40]	validation-rmse:6.64558
# [41]	validation-rmse:6.64364
# [42]	validation-rmse:6.64206
# [43]	validation-rmse:6.64030
# [44]	validation-rmse:6.63864
# [45]	validation-rmse:6.63702
# [46]	validation-rmse:6.63557
# [47]	validation-rmse:6.63441
# [48]	validation-rmse:6.63355
# [49]	validation-rmse:6.63225
# [50]	validation-rmse:6.63147
# [51]	validation-rmse:6.63043
# [52]	validation-rmse:6.62979
# [53]	validation-rmse:6.62914
# [54]	validation-rmse:6.62838
# [55]	validation-rmse:6.62744
# [56]	validation-rmse:6.62693
# [57]	validation-rmse:6.62603
# [58]	validation-rmse:6.62563
# [59]	validation-rmse:6.62468
# [60]	validation-rmse:6.62433
# [61]	validation-rmse:6.62375
# [62]	validation-rmse:6.62329
# [63]	validation-rmse:6.62285
# [64]	validation-rmse:6.62226
# [65]	validation-rmse:6.62179
# [66]	validation-rmse:6.62148
# [67]	validation-rmse:6.62090
# [68]	validation-rmse:6.62059
# [69]	validation-rmse:6.62022
# [70]	validation-rmse:6.61991
# [71]	validation-rmse:6.61974
# [72]	validation-rmse:6.61919
# [73]	validation-rmse:6.61898
# [74]	validation-rmse:6.61877
# [75]	validation-rmse:6.61859
# [76]	validation-rmse:6.61817
# [77]	validation-rmse:6.61795
# [78]	validation-rmse:6.61763
# [79]	validation-rmse:6.61749
# [80]	validation-rmse:6.61713
# [81]	validation-rmse:6.61696
# [82]	validation-rmse:6.61663
# [83]	validation-rmse:6.61655
# [84]	validation-rmse:6.61626
# [85]	validation-rmse:6.61544
# [86]	validation-rmse:6.61516
# [87]	validation-rmse:6.61502
# [88]	validation-rmse:6.61475
# [89]	validation-rmse:6.61455
# [90]	validation-rmse:6.61429
# [91]	validation-rmse:6.61394
# [92]	validation-rmse:6.61374
# [93]	validation-rmse:6.61352
# [94]	validation-rmse:6.61324
# [95]	validation-rmse:6.61311
# [96]	validation-rmse:6.61291
# [97]	validation-rmse:6.61288
# [98]	validation-rmse:6.61253
# [99]	validation-rmse:6.61237
# 100%|██████████| 10/10 [04:46<00:00, 28.69s/trial, best loss: 6.4093349239502]

# %%
# best hyper parameter combination that makes the lowest loss
best_result
# Out:
# {'learning_rate': np.float64(0.06795566766046571),
#  'max_depth': np.float64(74.0),
#  'min_child_weight': np.float64(1.1034760099449035),
#  'reg_alpha': np.float64(0.08418429054929681),
#  'reg_lambda': np.float64(0.007240669500118009)}

# %% [markdown]
# ### MLFlow auto logging
#
# I will try to train a new model with best hyper-parameters obtained from the previous step using mlflow.autolog
#
# Autolog works only for specific frameworks one of them is XGBoost

# %%
best_hps = {
  'learning_rate': 0.06795566766046571,
  'max_depth': 74,
  'min_child_weight': 1.1034760099449035,
  'reg_alpha': 0.08418429054929681,
  'reg_lambda': 0.007240669500118009,
  'objective': 'reg:squarederror',
  'seed': 42
}

# %%
mlflow.xgboost.autolog()

booster = xgb.train(
  params=best_hps,
  dtrain=train,
  num_boost_round=1000,
  evals=[(valid, "validation")],
  early_stopping_rounds=50
)
# Out:
# 2025/06/11 04:17:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '374d05143647477991b1e1c99275b53f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:11.65641
# [1]	validation-rmse:11.14813
# [2]	validation-rmse:10.68574
# [3]	validation-rmse:10.26421
# [4]	validation-rmse:9.88213
# [5]	validation-rmse:9.53492
# [6]	validation-rmse:9.22268
# [7]	validation-rmse:8.93914
# [8]	validation-rmse:8.68309
# [9]	validation-rmse:8.45363
# [10]	validation-rmse:8.24733
# [11]	validation-rmse:8.06091
# [12]	validation-rmse:7.89570
# [13]	validation-rmse:7.74545
# [14]	validation-rmse:7.61146
# [15]	validation-rmse:7.49190
# [16]	validation-rmse:7.38524
# [17]	validation-rmse:7.29063
# [18]	validation-rmse:7.20510
# [19]	validation-rmse:7.12936
# [20]	validation-rmse:7.06096
# [21]	validation-rmse:7.00094
# [22]	validation-rmse:6.94597
# [23]	validation-rmse:6.89824
# [24]	validation-rmse:6.85446
# [25]	validation-rmse:6.81548
# [26]	validation-rmse:6.78070
# [27]	validation-rmse:6.74898
# [28]	validation-rmse:6.71989
# [29]	validation-rmse:6.69555
# [30]	validation-rmse:6.67299
# [31]	validation-rmse:6.65151
# [32]	validation-rmse:6.63385
# [33]	validation-rmse:6.61697
# [34]	validation-rmse:6.60104
# [35]	validation-rmse:6.58731
# [36]	validation-rmse:6.57431
# [37]	validation-rmse:6.56257
# [38]	validation-rmse:6.55203
# [39]	validation-rmse:6.54221
# [40]	validation-rmse:6.53382
# [41]	validation-rmse:6.52492
# [42]	validation-rmse:6.51718
# [43]	validation-rmse:6.50959
# [44]	validation-rmse:6.50342
# [45]	validation-rmse:6.49788
# [46]	validation-rmse:6.49229
# [47]	validation-rmse:6.48734
# [48]	validation-rmse:6.48255
# [49]	validation-rmse:6.47794
# [50]	validation-rmse:6.47413
# [51]	validation-rmse:6.47001
# [52]	validation-rmse:6.46638
# [53]	validation-rmse:6.46311
# [54]	validation-rmse:6.46006
# [55]	validation-rmse:6.45658
# [56]	validation-rmse:6.45352
# [57]	validation-rmse:6.45104
# [58]	validation-rmse:6.44864
# [59]	validation-rmse:6.44606
# [60]	validation-rmse:6.44329
# [61]	validation-rmse:6.44103
# [62]	validation-rmse:6.43934
# [63]	validation-rmse:6.43769
# [64]	validation-rmse:6.43633
# [65]	validation-rmse:6.43474
# [66]	validation-rmse:6.43345
# [67]	validation-rmse:6.43211
# [68]	validation-rmse:6.43123
# [69]	validation-rmse:6.43029
# [70]	validation-rmse:6.42924
# [71]	validation-rmse:6.42831
# [72]	validation-rmse:6.42751
# [73]	validation-rmse:6.42666
# [74]	validation-rmse:6.42568
# [75]	validation-rmse:6.42468
# [76]	validation-rmse:6.42365
# [77]	validation-rmse:6.42254
# [78]	validation-rmse:6.42177
# [79]	validation-rmse:6.42133
# [80]	validation-rmse:6.42093
# [81]	validation-rmse:6.42024
# [82]	validation-rmse:6.41962
# [83]	validation-rmse:6.41913
# [84]	validation-rmse:6.41853
# [85]	validation-rmse:6.41788
# [86]	validation-rmse:6.41730
# [87]	validation-rmse:6.41646
# [88]	validation-rmse:6.41593
# [89]	validation-rmse:6.41518
# [90]	validation-rmse:6.41466
# [91]	validation-rmse:6.41394
# [92]	validation-rmse:6.41328
# [93]	validation-rmse:6.41248
# [94]	validation-rmse:6.41175
# [95]	validation-rmse:6.41126
# [96]	validation-rmse:6.41109
# [97]	validation-rmse:6.41050
# [98]	validation-rmse:6.40984
# [99]	validation-rmse:6.40933
# [100]	validation-rmse:6.40893
# [101]	validation-rmse:6.40822
# [102]	validation-rmse:6.40755
# [103]	validation-rmse:6.40678
# [104]	validation-rmse:6.40605
# [105]	validation-rmse:6.40521
# [106]	validation-rmse:6.40459
# [107]	validation-rmse:6.40408
# [108]	validation-rmse:6.40355
# [109]	validation-rmse:6.40303
# [110]	validation-rmse:6.40236
# [111]	validation-rmse:6.40194
# [112]	validation-rmse:6.40144
# [113]	validation-rmse:6.40103
# [114]	validation-rmse:6.40045
# [115]	validation-rmse:6.40007
# [116]	validation-rmse:6.39963
# [117]	validation-rmse:6.39917
# [118]	validation-rmse:6.39832
# [119]	validation-rmse:6.39781
# [120]	validation-rmse:6.39749
# [121]	validation-rmse:6.39710
# [122]	validation-rmse:6.39656
# [123]	validation-rmse:6.39617
# [124]	validation-rmse:6.39567
# [125]	validation-rmse:6.39536
# [126]	validation-rmse:6.39476
# [127]	validation-rmse:6.39447
# [128]	validation-rmse:6.39396
# [129]	validation-rmse:6.39363
# [130]	validation-rmse:6.39294
# [131]	validation-rmse:6.39263
# [132]	validation-rmse:6.39236
# [133]	validation-rmse:6.39192
# [134]	validation-rmse:6.39162
# [135]	validation-rmse:6.39124
# [136]	validation-rmse:6.39078
# [137]	validation-rmse:6.39031
# [138]	validation-rmse:6.38976
# [139]	validation-rmse:6.38936
# [140]	validation-rmse:6.38906
# [141]	validation-rmse:6.38865
# [142]	validation-rmse:6.38819
# [143]	validation-rmse:6.38788
# [144]	validation-rmse:6.38747
# [145]	validation-rmse:6.38716
# [146]	validation-rmse:6.38673
# [147]	validation-rmse:6.38643
# [148]	validation-rmse:6.38608
# [149]	validation-rmse:6.38583
# [150]	validation-rmse:6.38520
# [151]	validation-rmse:6.38484
# [152]	validation-rmse:6.38446
# [153]	validation-rmse:6.38418
# [154]	validation-rmse:6.38393
# [155]	validation-rmse:6.38350
# [156]	validation-rmse:6.38312
# [157]	validation-rmse:6.38283
# [158]	validation-rmse:6.38242
# [159]	validation-rmse:6.38218
# [160]	validation-rmse:6.38165
# [161]	validation-rmse:6.38139
# [162]	validation-rmse:6.38118
# [163]	validation-rmse:6.38083
# [164]	validation-rmse:6.38042
# [165]	validation-rmse:6.38015
# [166]	validation-rmse:6.37977
# [167]	validation-rmse:6.37953
# [168]	validation-rmse:6.37919
# [169]	validation-rmse:6.37899
# [170]	validation-rmse:6.37857
# [171]	validation-rmse:6.37833
# [172]	validation-rmse:6.37822
# [173]	validation-rmse:6.37784
# [174]	validation-rmse:6.37725
# [175]	validation-rmse:6.37706
# [176]	validation-rmse:6.37661
# [177]	validation-rmse:6.37637
# [178]	validation-rmse:6.37626
# [179]	validation-rmse:6.37582
# [180]	validation-rmse:6.37543
# [181]	validation-rmse:6.37521
# [182]	validation-rmse:6.37485
# [183]	validation-rmse:6.37464
# [184]	validation-rmse:6.37431
# [185]	validation-rmse:6.37404
# [186]	validation-rmse:6.37378
# [187]	validation-rmse:6.37363
# [188]	validation-rmse:6.37326
# [189]	validation-rmse:6.37293
# [190]	validation-rmse:6.37261
# [191]	validation-rmse:6.37234
# [192]	validation-rmse:6.37221
# [193]	validation-rmse:6.37193
# [194]	validation-rmse:6.37173
# [195]	validation-rmse:6.37127
# [196]	validation-rmse:6.37112
# [197]	validation-rmse:6.37081
# [198]	validation-rmse:6.37068
# [199]	validation-rmse:6.37047
# [200]	validation-rmse:6.37023
# [201]	validation-rmse:6.36980
# [202]	validation-rmse:6.36963
# [203]	validation-rmse:6.36936
# [204]	validation-rmse:6.36889
# [205]	validation-rmse:6.36874
# [206]	validation-rmse:6.36850
# [207]	validation-rmse:6.36827
# [208]	validation-rmse:6.36796
# [209]	validation-rmse:6.36765
# [210]	validation-rmse:6.36749
# [211]	validation-rmse:6.36712
# [212]	validation-rmse:6.36689
# [213]	validation-rmse:6.36665
# [214]	validation-rmse:6.36643
# [215]	validation-rmse:6.36628
# [216]	validation-rmse:6.36601
# [217]	validation-rmse:6.36557
# [218]	validation-rmse:6.36536
# [219]	validation-rmse:6.36510
# [220]	validation-rmse:6.36484
# [221]	validation-rmse:6.36472
# [222]	validation-rmse:6.36444
# [223]	validation-rmse:6.36427
# [224]	validation-rmse:6.36398
# [225]	validation-rmse:6.36388
# [226]	validation-rmse:6.36357
# [227]	validation-rmse:6.36323
# [228]	validation-rmse:6.36305
# [229]	validation-rmse:6.36288
# [230]	validation-rmse:6.36280
# [231]	validation-rmse:6.36267
# [232]	validation-rmse:6.36245
# [233]	validation-rmse:6.36207
# [234]	validation-rmse:6.36187
# [235]	validation-rmse:6.36166
# [236]	validation-rmse:6.36141
# [237]	validation-rmse:6.36111
# [238]	validation-rmse:6.36095
# [239]	validation-rmse:6.36070
# [240]	validation-rmse:6.36060
# [241]	validation-rmse:6.36047
# [242]	validation-rmse:6.36036
# [243]	validation-rmse:6.36005
# [244]	validation-rmse:6.35976
# [245]	validation-rmse:6.35969
# [246]	validation-rmse:6.35936
# [247]	validation-rmse:6.35917
# [248]	validation-rmse:6.35886
# [249]	validation-rmse:6.35882
# [250]	validation-rmse:6.35845
# [251]	validation-rmse:6.35832
# [252]	validation-rmse:6.35820
# [253]	validation-rmse:6.35796
# [254]	validation-rmse:6.35769
# [255]	validation-rmse:6.35737
# [256]	validation-rmse:6.35734
# [257]	validation-rmse:6.35711
# [258]	validation-rmse:6.35711
# [259]	validation-rmse:6.35677
# [260]	validation-rmse:6.35655
# [261]	validation-rmse:6.35658
# [262]	validation-rmse:6.35648
# [263]	validation-rmse:6.35631
# [264]	validation-rmse:6.35610
# [265]	validation-rmse:6.35584
# [266]	validation-rmse:6.35570
# [267]	validation-rmse:6.35560
# [268]	validation-rmse:6.35544
# [269]	validation-rmse:6.35523
# [270]	validation-rmse:6.35505
# [271]	validation-rmse:6.35490
# [272]	validation-rmse:6.35478
# [273]	validation-rmse:6.35454
# [274]	validation-rmse:6.35441
# [275]	validation-rmse:6.35423
# [276]	validation-rmse:6.35407
# [277]	validation-rmse:6.35395
# [278]	validation-rmse:6.35376
# [279]	validation-rmse:6.35352
# [280]	validation-rmse:6.35337
# [281]	validation-rmse:6.35324
# [282]	validation-rmse:6.35289
# [283]	validation-rmse:6.35257
# [284]	validation-rmse:6.35253
# [285]	validation-rmse:6.35235
# [286]	validation-rmse:6.35216
# [287]	validation-rmse:6.35215
# [288]	validation-rmse:6.35191
# [289]	validation-rmse:6.35171
# [290]	validation-rmse:6.35168
# [291]	validation-rmse:6.35162
# [292]	validation-rmse:6.35134
# [293]	validation-rmse:6.35118
# [294]	validation-rmse:6.35107
# [295]	validation-rmse:6.35103
# [296]	validation-rmse:6.35088
# [297]	validation-rmse:6.35056
# [298]	validation-rmse:6.35042
# [299]	validation-rmse:6.35035
# [300]	validation-rmse:6.35031
# [301]	validation-rmse:6.35010
# [302]	validation-rmse:6.34994
# [303]	validation-rmse:6.34982
# [304]	validation-rmse:6.34968
# [305]	validation-rmse:6.34955
# [306]	validation-rmse:6.34943
# [307]	validation-rmse:6.34931
# [308]	validation-rmse:6.34918
# [309]	validation-rmse:6.34900
# [310]	validation-rmse:6.34881
# [311]	validation-rmse:6.34864
# [312]	validation-rmse:6.34843
# [313]	validation-rmse:6.34835
# [314]	validation-rmse:6.34823
# [315]	validation-rmse:6.34794
# [316]	validation-rmse:6.34778
# [317]	validation-rmse:6.34750
# [318]	validation-rmse:6.34748
# [319]	validation-rmse:6.34724
# [320]	validation-rmse:6.34720
# [321]	validation-rmse:6.34708
# [322]	validation-rmse:6.34699
# [323]	validation-rmse:6.34689
# [324]	validation-rmse:6.34674
# [325]	validation-rmse:6.34671
# [326]	validation-rmse:6.34617
# [327]	validation-rmse:6.34614
# [328]	validation-rmse:6.34585
# [329]	validation-rmse:6.34568
# [330]	validation-rmse:6.34563
# [331]	validation-rmse:6.34555
# [332]	validation-rmse:6.34561
# [333]	validation-rmse:6.34552
# [334]	validation-rmse:6.34538
# [335]	validation-rmse:6.34527
# [336]	validation-rmse:6.34514
# [337]	validation-rmse:6.34510
# [338]	validation-rmse:6.34498
# [339]	validation-rmse:6.34502
# [340]	validation-rmse:6.34478
# [341]	validation-rmse:6.34464
# [342]	validation-rmse:6.34464
# [343]	validation-rmse:6.34415
# [344]	validation-rmse:6.34410
# [345]	validation-rmse:6.34416
# [346]	validation-rmse:6.34396
# [347]	validation-rmse:6.34398
# [348]	validation-rmse:6.34382
# [349]	validation-rmse:6.34369
# [350]	validation-rmse:6.34356
# [351]	validation-rmse:6.34346
# [352]	validation-rmse:6.34333
# [353]	validation-rmse:6.34331
# [354]	validation-rmse:6.34327
# [355]	validation-rmse:6.34317
# [356]	validation-rmse:6.34303
# [357]	validation-rmse:6.34299
# [358]	validation-rmse:6.34280
# [359]	validation-rmse:6.34267
# [360]	validation-rmse:6.34252
# [361]	validation-rmse:6.34235
# [362]	validation-rmse:6.34186
# [363]	validation-rmse:6.34184
# [364]	validation-rmse:6.34178
# [365]	validation-rmse:6.34163
# [366]	validation-rmse:6.34158
# [367]	validation-rmse:6.34157
# [368]	validation-rmse:6.34139
# [369]	validation-rmse:6.34126
# [370]	validation-rmse:6.34102
# [371]	validation-rmse:6.34092
# [372]	validation-rmse:6.34069
# [373]	validation-rmse:6.34080
# [374]	validation-rmse:6.34044
# [375]	validation-rmse:6.34042
# [376]	validation-rmse:6.34026
# [377]	validation-rmse:6.34012
# [378]	validation-rmse:6.34002
# [379]	validation-rmse:6.34008
# [380]	validation-rmse:6.33984
# [381]	validation-rmse:6.33967
# [382]	validation-rmse:6.33965
# [383]	validation-rmse:6.33950
# [384]	validation-rmse:6.33937
# [385]	validation-rmse:6.33933
# [386]	validation-rmse:6.33938
# [387]	validation-rmse:6.33938
# [388]	validation-rmse:6.33926
# [389]	validation-rmse:6.33917
# [390]	validation-rmse:6.33901
# [391]	validation-rmse:6.33891
# [392]	validation-rmse:6.33895
# [393]	validation-rmse:6.33880
# [394]	validation-rmse:6.33867
# [395]	validation-rmse:6.33862
# [396]	validation-rmse:6.33849
# [397]	validation-rmse:6.33843
# [398]	validation-rmse:6.33858
# [399]	validation-rmse:6.33849
# [400]	validation-rmse:6.33845
# [401]	validation-rmse:6.33841
# [402]	validation-rmse:6.33822
# [403]	validation-rmse:6.33811
# [404]	validation-rmse:6.33775
# [405]	validation-rmse:6.33768
# [406]	validation-rmse:6.33759
# [407]	validation-rmse:6.33761
# [408]	validation-rmse:6.33754
# [409]	validation-rmse:6.33745
# [410]	validation-rmse:6.33730
# [411]	validation-rmse:6.33718
# [412]	validation-rmse:6.33698
# [413]	validation-rmse:6.33682
# [414]	validation-rmse:6.33647
# [415]	validation-rmse:6.33657
# [416]	validation-rmse:6.33650
# [417]	validation-rmse:6.33636
# [418]	validation-rmse:6.33638
# [419]	validation-rmse:6.33643
# [420]	validation-rmse:6.33636
# [421]	validation-rmse:6.33631
# [422]	validation-rmse:6.33601
# [423]	validation-rmse:6.33582
# [424]	validation-rmse:6.33584
# [425]	validation-rmse:6.33564
# [426]	validation-rmse:6.33561
# [427]	validation-rmse:6.33547
# [428]	validation-rmse:6.33544
# [429]	validation-rmse:6.33536
# [430]	validation-rmse:6.33514
# [431]	validation-rmse:6.33509
# [432]	validation-rmse:6.33498
# [433]	validation-rmse:6.33493
# [434]	validation-rmse:6.33459
# [435]	validation-rmse:6.33464
# [436]	validation-rmse:6.33442
# [437]	validation-rmse:6.33426
# [438]	validation-rmse:6.33414
# [439]	validation-rmse:6.33406
# [440]	validation-rmse:6.33385
# [441]	validation-rmse:6.33384
# [442]	validation-rmse:6.33380
# [443]	validation-rmse:6.33382
# [444]	validation-rmse:6.33354
# [445]	validation-rmse:6.33355
# [446]	validation-rmse:6.33344
# [447]	validation-rmse:6.33345
# [448]	validation-rmse:6.33335
# [449]	validation-rmse:6.33322
# [450]	validation-rmse:6.33303
# [451]	validation-rmse:6.33297
# [452]	validation-rmse:6.33304
# [453]	validation-rmse:6.33302
# [454]	validation-rmse:6.33308
# [455]	validation-rmse:6.33294
# [456]	validation-rmse:6.33294
# [457]	validation-rmse:6.33303
# [458]	validation-rmse:6.33287
# [459]	validation-rmse:6.33289
# [460]	validation-rmse:6.33280
# [461]	validation-rmse:6.33273
# [462]	validation-rmse:6.33269
# [463]	validation-rmse:6.33257
# [464]	validation-rmse:6.33256
# [465]	validation-rmse:6.33251
# [466]	validation-rmse:6.33246
# [467]	validation-rmse:6.33230
# [468]	validation-rmse:6.33228
# [469]	validation-rmse:6.33220
# [470]	validation-rmse:6.33210
# [471]	validation-rmse:6.33202
# [472]	validation-rmse:6.33177
# [473]	validation-rmse:6.33171
# [474]	validation-rmse:6.33158
# [475]	validation-rmse:6.33151
# [476]	validation-rmse:6.33148
# [477]	validation-rmse:6.33124
# [478]	validation-rmse:6.33125
# [479]	validation-rmse:6.33125
# [480]	validation-rmse:6.33125
# [481]	validation-rmse:6.33116
# [482]	validation-rmse:6.33108
# [483]	validation-rmse:6.33078
# [484]	validation-rmse:6.33085
# [485]	validation-rmse:6.33087
# [486]	validation-rmse:6.33074
# [487]	validation-rmse:6.33074
# [488]	validation-rmse:6.33072
# [489]	validation-rmse:6.33061
# [490]	validation-rmse:6.33056
# [491]	validation-rmse:6.33061
# [492]	validation-rmse:6.33059
# [493]	validation-rmse:6.33056
# [494]	validation-rmse:6.33043
# [495]	validation-rmse:6.33037
# [496]	validation-rmse:6.33032
# [497]	validation-rmse:6.33034
# [498]	validation-rmse:6.33034
# [499]	validation-rmse:6.33019
# [500]	validation-rmse:6.32997
# [501]	validation-rmse:6.32992
# [502]	validation-rmse:6.32966
# [503]	validation-rmse:6.32977
# [504]	validation-rmse:6.32961
# [505]	validation-rmse:6.32964
# [506]	validation-rmse:6.32956
# [507]	validation-rmse:6.32952
# [508]	validation-rmse:6.32944
# [509]	validation-rmse:6.32942
# [510]	validation-rmse:6.32933
# [511]	validation-rmse:6.32913
# [512]	validation-rmse:6.32901
# [513]	validation-rmse:6.32905
# [514]	validation-rmse:6.32920
# [515]	validation-rmse:6.32917
# [516]	validation-rmse:6.32917
# [517]	validation-rmse:6.32917
# [518]	validation-rmse:6.32907
# [519]	validation-rmse:6.32896
# [520]	validation-rmse:6.32900
# [521]	validation-rmse:6.32881
# [522]	validation-rmse:6.32872
# [523]	validation-rmse:6.32854
# [524]	validation-rmse:6.32855
# [525]	validation-rmse:6.32867
# [526]	validation-rmse:6.32834
# [527]	validation-rmse:6.32819
# [528]	validation-rmse:6.32825
# [529]	validation-rmse:6.32824
# [530]	validation-rmse:6.32823
# [531]	validation-rmse:6.32824
# [532]	validation-rmse:6.32806
# [533]	validation-rmse:6.32791
# [534]	validation-rmse:6.32778
# [535]	validation-rmse:6.32758
# [536]	validation-rmse:6.32760
# [537]	validation-rmse:6.32758
# [538]	validation-rmse:6.32740
# [539]	validation-rmse:6.32738
# [540]	validation-rmse:6.32744
# [541]	validation-rmse:6.32729
# [542]	validation-rmse:6.32726
# [543]	validation-rmse:6.32721
# [544]	validation-rmse:6.32712
# [545]	validation-rmse:6.32706
# [546]	validation-rmse:6.32696
# [547]	validation-rmse:6.32693
# [548]	validation-rmse:6.32698
# [549]	validation-rmse:6.32685
# [550]	validation-rmse:6.32678
# [551]	validation-rmse:6.32695
# [552]	validation-rmse:6.32688
# [553]	validation-rmse:6.32694
# [554]	validation-rmse:6.32685
# [555]	validation-rmse:6.32669
# [556]	validation-rmse:6.32667
# [557]	validation-rmse:6.32666
# [558]	validation-rmse:6.32656
# [559]	validation-rmse:6.32645
# [560]	validation-rmse:6.32644
# [561]	validation-rmse:6.32630
# [562]	validation-rmse:6.32633
# [563]	validation-rmse:6.32621
# [564]	validation-rmse:6.32631
# [565]	validation-rmse:6.32638
# [566]	validation-rmse:6.32637
# [567]	validation-rmse:6.32645
# [568]	validation-rmse:6.32625
# [569]	validation-rmse:6.32626
# [570]	validation-rmse:6.32616
# [571]	validation-rmse:6.32623
# [572]	validation-rmse:6.32633
# [573]	validation-rmse:6.32621
# [574]	validation-rmse:6.32615
# [575]	validation-rmse:6.32628
# [576]	validation-rmse:6.32626
# [577]	validation-rmse:6.32618
# [578]	validation-rmse:6.32612
# [579]	validation-rmse:6.32607
# [580]	validation-rmse:6.32599
# [581]	validation-rmse:6.32607
# [582]	validation-rmse:6.32590
# [583]	validation-rmse:6.32578
# [584]	validation-rmse:6.32583
# [585]	validation-rmse:6.32578
# [586]	validation-rmse:6.32579
# [587]	validation-rmse:6.32574
# [588]	validation-rmse:6.32579
# [589]	validation-rmse:6.32577
# [590]	validation-rmse:6.32573
# [591]	validation-rmse:6.32570
# [592]	validation-rmse:6.32570
# [593]	validation-rmse:6.32551
# [594]	validation-rmse:6.32540
# [595]	validation-rmse:6.32543
# [596]	validation-rmse:6.32536
# [597]	validation-rmse:6.32533
# [598]	validation-rmse:6.32519
# [599]	validation-rmse:6.32514
# [600]	validation-rmse:6.32510
# [601]	validation-rmse:6.32503
# [602]	validation-rmse:6.32502
# [603]	validation-rmse:6.32494
# [604]	validation-rmse:6.32488
# [605]	validation-rmse:6.32478
# [606]	validation-rmse:6.32481
# [607]	validation-rmse:6.32474
# [608]	validation-rmse:6.32452
# [609]	validation-rmse:6.32467
# [610]	validation-rmse:6.32469
# [611]	validation-rmse:6.32454
# [612]	validation-rmse:6.32441
# [613]	validation-rmse:6.32447
# [614]	validation-rmse:6.32443
# [615]	validation-rmse:6.32444
# [616]	validation-rmse:6.32437
# [617]	validation-rmse:6.32438
# [618]	validation-rmse:6.32436
# [619]	validation-rmse:6.32430
# [620]	validation-rmse:6.32427
# [621]	validation-rmse:6.32423
# [622]	validation-rmse:6.32423
# [623]	validation-rmse:6.32427
# [624]	validation-rmse:6.32424
# [625]	validation-rmse:6.32427
# [626]	validation-rmse:6.32434
# [627]	validation-rmse:6.32434
# [628]	validation-rmse:6.32423
# [629]	validation-rmse:6.32427
# [630]	validation-rmse:6.32421
# [631]	validation-rmse:6.32413
# [632]	validation-rmse:6.32420
# [633]	validation-rmse:6.32410
# [634]	validation-rmse:6.32411
# [635]	validation-rmse:6.32408
# [636]	validation-rmse:6.32407
# [637]	validation-rmse:6.32401
# [638]	validation-rmse:6.32388
# [639]	validation-rmse:6.32388
# [640]	validation-rmse:6.32387
# [641]	validation-rmse:6.32367
# [642]	validation-rmse:6.32364
# [643]	validation-rmse:6.32371
# [644]	validation-rmse:6.32368
# [645]	validation-rmse:6.32365
# [646]	validation-rmse:6.32363
# [647]	validation-rmse:6.32361
# [648]	validation-rmse:6.32359
# [649]	validation-rmse:6.32373
# [650]	validation-rmse:6.32375
# [651]	validation-rmse:6.32382
# [652]	validation-rmse:6.32384
# [653]	validation-rmse:6.32378
# [654]	validation-rmse:6.32380
# [655]	validation-rmse:6.32390
# [656]	validation-rmse:6.32381
# [657]	validation-rmse:6.32378
# [658]	validation-rmse:6.32379
# [659]	validation-rmse:6.32387
# [660]	validation-rmse:6.32390
# [661]	validation-rmse:6.32374
# [662]	validation-rmse:6.32379
# [663]	validation-rmse:6.32371
# [664]	validation-rmse:6.32361
# [665]	validation-rmse:6.32352
# [666]	validation-rmse:6.32354
# [667]	validation-rmse:6.32349
# [668]	validation-rmse:6.32344
# [669]	validation-rmse:6.32341
# [670]	validation-rmse:6.32324
# [671]	validation-rmse:6.32317
# [672]	validation-rmse:6.32323
# [673]	validation-rmse:6.32318
# [674]	validation-rmse:6.32318
# [675]	validation-rmse:6.32322
# [676]	validation-rmse:6.32313
# [677]	validation-rmse:6.32315
# [678]	validation-rmse:6.32313
# [679]	validation-rmse:6.32315
# [680]	validation-rmse:6.32314
# [681]	validation-rmse:6.32300
# [682]	validation-rmse:6.32292
# [683]	validation-rmse:6.32287
# [684]	validation-rmse:6.32288
# [685]	validation-rmse:6.32297
# [686]	validation-rmse:6.32294
# [687]	validation-rmse:6.32286
# [688]	validation-rmse:6.32289
# [689]	validation-rmse:6.32296
# [690]	validation-rmse:6.32298
# [691]	validation-rmse:6.32298
# [692]	validation-rmse:6.32299
# [693]	validation-rmse:6.32299
# [694]	validation-rmse:6.32302
# [695]	validation-rmse:6.32317
# [696]	validation-rmse:6.32315
# [697]	validation-rmse:6.32308
# [698]	validation-rmse:6.32295
# [699]	validation-rmse:6.32292
# [700]	validation-rmse:6.32304
# [701]	validation-rmse:6.32298
# [702]	validation-rmse:6.32293
# [703]	validation-rmse:6.32294
# [704]	validation-rmse:6.32302
# [705]	validation-rmse:6.32306
# [706]	validation-rmse:6.32310
# [707]	validation-rmse:6.32280
# [708]	validation-rmse:6.32264
# [709]	validation-rmse:6.32263
# [710]	validation-rmse:6.32246
# [711]	validation-rmse:6.32248
# [712]	validation-rmse:6.32244
# [713]	validation-rmse:6.32245
# [714]	validation-rmse:6.32249
# [715]	validation-rmse:6.32251
# [716]	validation-rmse:6.32250
# [717]	validation-rmse:6.32248
# [718]	validation-rmse:6.32246
# [719]	validation-rmse:6.32245
# [720]	validation-rmse:6.32246
# [721]	validation-rmse:6.32234
# [722]	validation-rmse:6.32236
# [723]	validation-rmse:6.32236
# [724]	validation-rmse:6.32232
# [725]	validation-rmse:6.32229
# [726]	validation-rmse:6.32225
# [727]	validation-rmse:6.32219
# [728]	validation-rmse:6.32220
# [729]	validation-rmse:6.32220
# [730]	validation-rmse:6.32223
# [731]	validation-rmse:6.32219
# [732]	validation-rmse:6.32224
# [733]	validation-rmse:6.32230
# [734]	validation-rmse:6.32241
# [735]	validation-rmse:6.32242
# [736]	validation-rmse:6.32235
# [737]	validation-rmse:6.32247
# [738]	validation-rmse:6.32237
# [739]	validation-rmse:6.32237
# [740]	validation-rmse:6.32237
# [741]	validation-rmse:6.32239
# [742]	validation-rmse:6.32247
# [743]	validation-rmse:6.32244
# [744]	validation-rmse:6.32247
# [745]	validation-rmse:6.32243
# [746]	validation-rmse:6.32236
# [747]	validation-rmse:6.32237
# [748]	validation-rmse:6.32239
# [749]	validation-rmse:6.32240
# [750]	validation-rmse:6.32265
# [751]	validation-rmse:6.32254
# [752]	validation-rmse:6.32248
# [753]	validation-rmse:6.32245
# [754]	validation-rmse:6.32246
# [755]	validation-rmse:6.32250
# [756]	validation-rmse:6.32264
# [757]	validation-rmse:6.32262
# [758]	validation-rmse:6.32254
# [759]	validation-rmse:6.32259
# [760]	validation-rmse:6.32250
# [761]	validation-rmse:6.32248
# [762]	validation-rmse:6.32247
# [763]	validation-rmse:6.32242
# [764]	validation-rmse:6.32237
# [765]	validation-rmse:6.32240
# [766]	validation-rmse:6.32236
# [767]	validation-rmse:6.32231
# [768]	validation-rmse:6.32233
# [769]	validation-rmse:6.32235
# [770]	validation-rmse:6.32235
# [771]	validation-rmse:6.32225
# [772]	validation-rmse:6.32225
# [773]	validation-rmse:6.32221
# [774]	validation-rmse:6.32222
# [775]	validation-rmse:6.32223
# [776]	validation-rmse:6.32211
# [777]	validation-rmse:6.32215
# [778]	validation-rmse:6.32224
# [779]	validation-rmse:6.32226
# [780]	validation-rmse:6.32226
# [781]	validation-rmse:6.32222
# [782]	validation-rmse:6.32221
# [783]	validation-rmse:6.32213
# [784]	validation-rmse:6.32206
# [785]	validation-rmse:6.32202
# [786]	validation-rmse:6.32197
# [787]	validation-rmse:6.32204
# [788]	validation-rmse:6.32202
# [789]	validation-rmse:6.32201
# [790]	validation-rmse:6.32201
# [791]	validation-rmse:6.32196
# [792]	validation-rmse:6.32209
# [793]	validation-rmse:6.32211
# [794]	validation-rmse:6.32220
# [795]	validation-rmse:6.32225
# [796]	validation-rmse:6.32217
# [797]	validation-rmse:6.32218
# [798]	validation-rmse:6.32211
# [799]	validation-rmse:6.32213
# [800]	validation-rmse:6.32211
# [801]	validation-rmse:6.32217
# [802]	validation-rmse:6.32217
# [803]	validation-rmse:6.32205
# [804]	validation-rmse:6.32205
# [805]	validation-rmse:6.32192
# [806]	validation-rmse:6.32194
# [807]	validation-rmse:6.32190
# [808]	validation-rmse:6.32190
# [809]	validation-rmse:6.32193
# [810]	validation-rmse:6.32199
# [811]	validation-rmse:6.32204
# [812]	validation-rmse:6.32206
# [813]	validation-rmse:6.32209
# [814]	validation-rmse:6.32216
# [815]	validation-rmse:6.32217
# [816]	validation-rmse:6.32227
# [817]	validation-rmse:6.32239
# [818]	validation-rmse:6.32240
# [819]	validation-rmse:6.32246
# [820]	validation-rmse:6.32270
# [821]	validation-rmse:6.32260
# [822]	validation-rmse:6.32278
# [823]	validation-rmse:6.32278
# [824]	validation-rmse:6.32278
# [825]	validation-rmse:6.32289
# [826]	validation-rmse:6.32289
# [827]	validation-rmse:6.32288
# [828]	validation-rmse:6.32318
# [829]	validation-rmse:6.32324
# [830]	validation-rmse:6.32322
# [831]	validation-rmse:6.32319
# [832]	validation-rmse:6.32318
# [833]	validation-rmse:6.32314
# [834]	validation-rmse:6.32312
# [835]	validation-rmse:6.32319
# [836]	validation-rmse:6.32319
# [837]	validation-rmse:6.32320
# [838]	validation-rmse:6.32337
# [839]	validation-rmse:6.32330
# [840]	validation-rmse:6.32332
# [841]	validation-rmse:6.32297
# [842]	validation-rmse:6.32293
# [843]	validation-rmse:6.32289
# [844]	validation-rmse:6.32282
# [845]	validation-rmse:6.32282
# [846]	validation-rmse:6.32268
# [847]	validation-rmse:6.32276
# [848]	validation-rmse:6.32273
# [849]	validation-rmse:6.32263
# [850]	validation-rmse:6.32265
# [851]	validation-rmse:6.32257
# [852]	validation-rmse:6.32254
# [853]	validation-rmse:6.32248
# [854]	validation-rmse:6.32238
# [855]	validation-rmse:6.32233
# [856]	validation-rmse:6.32238
# [857]	validation-rmse:6.32240
# 2025/06/11 04:21:15 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2025/06/11 04:21:15 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/codespace/anaconda3/envs/mlflow-tracking/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [04:21:15] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/06/11 04:21:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# ### Loading the model and make predictions

# %%
import mlflow

model_uri = 'runs:/374d05143647477991b1e1c99275b53f/model'

# Verify the model with the provided input data using the logged dependencies.
# For more details, refer to:
# https://mlflow.org/docs/latest/models.html#validate-models-before-deployment
mlflow.models.predict(
    model_uri=model_uri,
    input_data=X_val[0],
    env_manager="uv",
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
